# %%
import pandas as pd
import numpy as np
from import_gdc import ImportGDC
from import_hpa import ImportHPA
from import_string import ImportSTRING
from import_dgn import ImportDGN
from create_node2vec_embeddings import Runnode2vec
# Out:
# ['__annotations__', '__builtins__', '__call__', '__class__', '__closure__', '__code__', '__defaults__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__get__', '__getattribute__', '__globals__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__kwdefaults__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']

# %% [markdown]
# Import National Institute of Health Genomic Data Commons (GDA) and Human Protein Atlas (HPA) Data

# %%
# Process the gdc dataset to include only desired columns and scores
gdc = ImportGDC()
gdc
# Out:
#                ensembl  nih_ssm_in_cohort  nih_ssm_across_gdc  nih_cnv_gain  \
# 0      ENSG00000147481           0.144621            0.028155      0.076023
# 1      ENSG00000105877           0.144621            0.084772      0.074074
# 2      ENSG00000188107           0.144621            0.068585      0.111111
# 3      ENSG00000125414           0.144621            0.062601      0.005848
# 4      ENSG00000009694           0.144621            0.071653      0.052632
# ...                ...                ...                 ...           ...
# 21087  ENSG00000146648           0.146384            0.052244      0.105263
# 21088  ENSG00000133958           0.146384            0.059916      0.025341
# 21089  ENSG00000134376           0.146384            0.056617      0.085770
# 21090  ENSG00000109061           0.146384            0.057691      0.009747
# 21091  ENSG00000134516           0.146384            0.054622      0.066277
#
#        nih_cnv_loss  nih_tot_mutations
# 0          0.056530                 92
# 1          0.007797                105
# 2          0.056530                 95
# 3          0.042885                 95
# 4          0.025341                110
# ...             ...                ...
# 21087      0.019493                 51
# 21088      0.046784                110
# 21089      0.007797                 93
# 21090      0.040936                 93
# 21091      0.033138                103
#
# [21092 rows x 6 columns]

# %%
hpa = ImportHPA()
hpa
# Out:
# /Users/kubotan/Documents/github/lenskai/geneDRAGNN/data_preprocessing/import_hpa.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hpa_features["Tissue RNA - lung [NX]"] = (hpa_features["Tissue RNA - lung [NX]"] - hpa_features["Tissue RNA - lung [NX]"].mean()) / hpa_features["Tissue RNA - lung [NX]"].std()
# /Users/kubotan/Documents/github/lenskai/geneDRAGNN/data_preprocessing/import_hpa.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hpa_features[col] = (hpa_features[col] - hpa_features[col].mean()) / hpa_features[col].std()
#                ensembl     hpa_0     hpa_1     hpa_2     hpa_3     hpa_4  \
# 0      ENSG00000175899  0.443505  0.313574  0.430307 -0.285337 -0.351412
# 1      ENSG00000128274  0.532289  0.789331 -0.122159  0.019000  1.427162
# 2      ENSG00000094914  1.605229  0.936681  0.345886  0.183699 -1.001764
# 3      ENSG00000081760  0.467196  0.690415 -0.066723  0.335478  1.017124
# 4      ENSG00000114771  0.956718  0.202132 -0.490047 -0.524460  0.467132
# ...                ...       ...       ...       ...       ...       ...
# 15008  ENSG00000198455  1.436813 -1.455513  0.510199  0.224208  0.323736
# 15009  ENSG00000070476  1.140170 -1.162868  0.551409  0.127004  0.119115
# 15010  ENSG00000162378  0.782655 -0.057857 -0.397211  0.017498 -0.135123
# 15011  ENSG00000159840  1.042306  0.183392 -0.327697  0.065425 -0.459893
# 15012  ENSG00000074755  0.553160  0.068709  0.013208  0.760541  0.592771
#
#           hpa_5     hpa_6     hpa_7     hpa_8  ...    hpa_90    hpa_91  \
# 0      1.545059 -0.450936  0.444200 -0.116774  ...  0.006320 -0.027888
# 1     -0.065659  0.001669 -0.386983 -0.028900  ...  0.149074  0.178769
# 2     -0.846346  0.550995 -0.368205  0.202731  ...  0.279925 -0.048768
# 3      0.029579 -0.131714 -0.212387  0.075120  ... -0.235705 -0.227364
# 4     -0.207775 -0.494652 -0.192615  0.077836  ... -0.001358 -0.001869
# ...         ...       ...       ...       ...  ...       ...       ...
# 15008 -0.171141 -0.060697 -0.088626  0.103071  ... -0.005665  0.051799
# 15009 -0.120434 -0.421260 -0.798186  0.041917  ...  0.012090  0.041519
# 15010 -0.248882 -0.438176 -0.113363 -0.295955  ...  0.040491  0.000239
# 15011  0.507171 -0.610148 -0.067066  0.368216  ...  0.096770 -0.040477
# 15012 -0.094544  0.326136  0.636445  0.047971  ...  0.013039  0.009342
#
#          hpa_92    hpa_93    hpa_94    hpa_95    hpa_96    hpa_97    hpa_98  \
# 0     -0.107547  0.022017 -0.050586  0.051574  0.347056  0.569412  0.463967
# 1     -0.040884  0.223560 -0.012035 -0.075711 -0.083671  0.051758 -0.024050
# 2     -0.030550 -0.387925 -0.113770 -0.121910  0.103944  0.061019  0.284042
# 3     -0.037343 -0.135963  0.100348  0.069964 -0.039196  0.172889  0.022631
# 4     -0.004413  0.000176  0.003360 -0.012335 -0.003127  0.002467  0.014795
# ...         ...       ...       ...       ...       ...       ...       ...
# 15008 -0.023842 -0.019616  0.003056  0.000150  0.039306 -0.013828  0.013099
# 15009 -0.014106 -0.010610  0.011035  0.006470  0.048883 -0.011266  0.015886
# 15010  0.025405 -0.000228  0.025067  0.031722 -0.009675  0.012683 -0.016501
# 15011 -0.259790 -0.057269  0.521971 -0.082072 -0.098982  0.019590 -0.092667
# 15012 -0.000363 -0.001456 -0.002757 -0.020933  0.003012  0.011132 -0.004498
#
#          hpa_99
# 0      0.647494
# 1     -0.098001
# 2     -0.008951
# 3      0.190920
# 4     -0.006151
# ...         ...
# 15008  0.002627
# 15009 -0.002143
# 15010 -0.033751
# 15011  0.034596
# 15012  0.002359
#
# [15013 rows x 101 columns]

# %%
master = hpa.merge(gdc, on="ensembl")
master
# Out:
#                ensembl     hpa_0     hpa_1     hpa_2     hpa_3     hpa_4  \
# 0      ENSG00000175899  0.443505  0.313574  0.430307 -0.285337 -0.351412
# 1      ENSG00000128274  0.532289  0.789331 -0.122159  0.019000  1.427162
# 2      ENSG00000094914  1.605229  0.936681  0.345886  0.183699 -1.001764
# 3      ENSG00000081760  0.467196  0.690415 -0.066723  0.335478  1.017124
# 4      ENSG00000114771  0.956718  0.202132 -0.490047 -0.524460  0.467132
# ...                ...       ...       ...       ...       ...       ...
# 14893  ENSG00000198455  1.436813 -1.455513  0.510199  0.224208  0.323736
# 14894  ENSG00000070476  1.140170 -1.162868  0.551409  0.127004  0.119115
# 14895  ENSG00000162378  0.782655 -0.057857 -0.397211  0.017498 -0.135123
# 14896  ENSG00000159840  1.042306  0.183392 -0.327697  0.065425 -0.459893
# 14897  ENSG00000074755  0.553160  0.068709  0.013208  0.760541  0.592771
#
#           hpa_5     hpa_6     hpa_7     hpa_8  ...    hpa_95    hpa_96  \
# 0      1.545059 -0.450936  0.444200 -0.116774  ...  0.051574  0.347056
# 1     -0.065659  0.001669 -0.386983 -0.028900  ... -0.075711 -0.083671
# 2     -0.846346  0.550995 -0.368205  0.202731  ... -0.121910  0.103944
# 3      0.029579 -0.131714 -0.212387  0.075120  ...  0.069964 -0.039196
# 4     -0.207775 -0.494652 -0.192615  0.077836  ... -0.012335 -0.003127
# ...         ...       ...       ...       ...  ...       ...       ...
# 14893 -0.171141 -0.060697 -0.088626  0.103071  ...  0.000150  0.039306
# 14894 -0.120434 -0.421260 -0.798186  0.041917  ...  0.006470  0.048883
# 14895 -0.248882 -0.438176 -0.113363 -0.295955  ...  0.031722 -0.009675
# 14896  0.507171 -0.610148 -0.067066  0.368216  ... -0.082072 -0.098982
# 14897 -0.094544  0.326136  0.636445  0.047971  ... -0.020933  0.003012
#
#          hpa_97    hpa_98    hpa_99  nih_ssm_in_cohort  nih_ssm_across_gdc  \
# 0      0.569412  0.463967  0.647494           0.049383            0.031607
# 1      0.051758 -0.024050 -0.098001           0.001764            0.009436
# 2      0.061019  0.284042 -0.008951           0.005291            0.008822
# 3      0.172889  0.022631  0.190920           0.031746            0.015036
# 4      0.002467  0.014795 -0.006151           0.010582            0.010817
# ...         ...       ...       ...                ...                 ...
# 14893 -0.013828  0.013099  0.002627           0.024691            0.023168
# 14894 -0.011266  0.015886 -0.002143           0.014109            0.013195
# 14895  0.012683 -0.016501 -0.033751           0.022928            0.011891
# 14896  0.019590 -0.092667  0.034596           0.012346            0.011047
# 14897  0.011132 -0.004498  0.002359           0.044092            0.035827
#
#        nih_cnv_gain  nih_cnv_loss  nih_tot_mutations
# 0          0.042885      0.066277                 29
# 1          0.048733      0.025341                  1
# 2          0.068226      0.019493                  3
# 3          0.038986      0.052632                 19
# 4          0.066277      0.011696                  6
# ...             ...           ...                ...
# 14893      0.033138      0.011696                 16
# 14894      0.033138      0.015595                 10
# 14895      0.035088      0.048733                 14
# 14896      0.064327      0.023392                  8
# 14897      0.011696      0.046784                 26
#
# [14898 rows x 106 columns]

# %% [markdown]
# Import STRING Dataset

# %%
el = ImportSTRING()
el
# Out:
# Original Size:  11938498

# %% [markdown]
# Intersect Edge List (STRING) and Node Features (HPA and NIH/GDC) to Create LS-fGIN

# %%
el_allgenes = pd.concat([el['protein1'], el['protein2']]).drop_duplicates()
master = master[master['ensembl'].isin(el_allgenes)]

master
# Out:
#                ensembl     hpa_0     hpa_1     hpa_2     hpa_3     hpa_4  \
# 0      ENSG00000175899  0.443505  0.313574  0.430307 -0.285337 -0.351412
# 1      ENSG00000128274  0.532289  0.789331 -0.122159  0.019000  1.427162
# 2      ENSG00000094914  1.605229  0.936681  0.345886  0.183699 -1.001764
# 3      ENSG00000081760  0.467196  0.690415 -0.066723  0.335478  1.017124
# 4      ENSG00000114771  0.956718  0.202132 -0.490047 -0.524460  0.467132
# ...                ...       ...       ...       ...       ...       ...
# 14893  ENSG00000198455  1.436813 -1.455513  0.510199  0.224208  0.323736
# 14894  ENSG00000070476  1.140170 -1.162868  0.551409  0.127004  0.119115
# 14895  ENSG00000162378  0.782655 -0.057857 -0.397211  0.017498 -0.135123
# 14896  ENSG00000159840  1.042306  0.183392 -0.327697  0.065425 -0.459893
# 14897  ENSG00000074755  0.553160  0.068709  0.013208  0.760541  0.592771
#
#           hpa_5     hpa_6     hpa_7     hpa_8  ...    hpa_95    hpa_96  \
# 0      1.545059 -0.450936  0.444200 -0.116774  ... -0.433405 -0.146413
# 1     -0.065659  0.001669 -0.386983 -0.028900  ... -0.031864 -0.237453
# 2     -0.846346  0.550995 -0.368205  0.202731  ...  0.230434 -0.010382
# 3      0.029579 -0.131714 -0.212387  0.075120  ... -0.114822  0.139623
# 4     -0.207775 -0.494652 -0.192615  0.077836  ...  0.002585 -0.023332
# ...         ...       ...       ...       ...  ...       ...       ...
# 14893 -0.171141 -0.060697 -0.088626  0.103071  ...  0.015687  0.005540
# 14894 -0.120434 -0.421260 -0.798186  0.041917  ...  0.007485  0.012514
# 14895 -0.248882 -0.438176 -0.113363 -0.295955  ... -0.008147  0.017204
# 14896  0.507171 -0.610148 -0.067066  0.368216  ... -0.073462  0.159409
# 14897 -0.094544  0.326136  0.636445  0.047971  ...  0.008076 -0.011302
#
#          hpa_97    hpa_98    hpa_99  nih_ssm_in_cohort  nih_ssm_across_gdc  \
# 0     -0.267809 -0.392097 -0.029558           0.049383            0.031607
# 1     -0.033583 -0.111348  0.173074           0.001764            0.009436
# 2     -0.032331  0.439249 -0.054759           0.005291            0.008822
# 3      0.119554  0.267122 -0.027929           0.031746            0.015036
# 4      0.017401 -0.008516  0.005111           0.010582            0.010817
# ...         ...       ...       ...                ...                 ...
# 14893  0.017016  0.002985  0.003818           0.024691            0.023168
# 14894  0.036679  0.000581 -0.001755           0.014109            0.013195
# 14895 -0.058443  0.000587  0.032731           0.022928            0.011891
# 14896 -0.126625 -0.073672 -0.004626           0.012346            0.011047
# 14897 -0.006043 -0.008143  0.005338           0.044092            0.035827
#
#        nih_cnv_gain  nih_cnv_loss  nih_tot_mutations
# 0          0.042885      0.066277                 29
# 1          0.048733      0.025341                  1
# 2          0.068226      0.019493                  3
# 3          0.038986      0.052632                 19
# 4          0.066277      0.011696                  6
# ...             ...           ...                ...
# 14893      0.033138      0.011696                 16
# 14894      0.033138      0.015595                 10
# 14895      0.035088      0.048733                 14
# 14896      0.064327      0.023392                  8
# 14897      0.011696      0.046784                 26
#
# [14855 rows x 106 columns]

# %%
el_intersect = el.iloc[:, :2].merge(master["ensembl"], right_on="ensembl", left_on='protein1').drop("ensembl", axis=1)
el_intersect = el_intersect.merge(master["ensembl"], right_on="ensembl", left_on='protein2').drop("ensembl", axis=1).rename(columns={'protein1':'gene1', 'protein2':'gene2'})
el = el_intersect.merge(el, right_on=['protein1', 'protein2'], left_on=['gene1', 'gene2']).drop(['protein1','protein2'], axis=1)
el
# Out:
#                    gene1            gene2  neighborhood  fusion  cooccurence  \
# 0        ENSG00000004059  ENSG00000154678             0       0            0
# 1        ENSG00000004059  ENSG00000180370             0       0            0
# 2        ENSG00000004059  ENSG00000100228             0       0            0
# 3        ENSG00000004059  ENSG00000107263             0       0            0
# 4        ENSG00000004059  ENSG00000184900             0       0            0
# ...                  ...              ...           ...     ...          ...
# 4405636  ENSG00000070367  ENSG00000280433             0       0            0
# 4405637  ENSG00000278845  ENSG00000239900             0       0            0
# 4405638  ENSG00000278845  ENSG00000179583             0       0            0
# 4405639  ENSG00000179242  ENSG00000197410             0       0            0
# 4405640  ENSG00000239900  ENSG00000100129             0       0            0
#
#          coexpression  experimental  database  textmining  combined_score
# 0                  54             0         0         144             155
# 1                   0           180         0          61             197
# 2                  62           152         0         101             222
# 3                   0           161         0          64             181
# 4                  82           213         0          72             270
# ...               ...           ...       ...         ...             ...
# 4405636            87           182         0         251             391
# 4405637           191             0         0           0             190
# 4405638            59             0         0         228             242
# 4405639            52           154         0         100             215
# 4405640           149             0         0          55             161
#
# [4405641 rows x 10 columns]

# %%
el[['gene1', 'gene2']].to_csv('../data/final_data/ls-fgin_edge_list.edg', index=False, header=False, sep='\t') 
el.to_csv('../data/final_data/ls-fgin_edge_list_features.edg', index=False)

# %% [markdown]
# Import Disease Gene Network and Intersect with Master

# %%
dgn = ImportDGN()
dgn = dgn.loc[dgn['ensembl'].isin(master['ensembl'])]
dgn
# Out:
#              ensembl  gda_score
# 1    ENSG00000196839          1
# 7    ENSG00000153094          1
# 8    ENSG00000111252          1
# 16   ENSG00000269897          1
# 17   ENSG00000204410          1
# ..               ...        ...
# 978  ENSG00000169554          1
# 979  ENSG00000117399          1
# 980  ENSG00000116688          1
# 981  ENSG00000013364          1
# 982  ENSG00000039068          1
#
# [778 rows x 2 columns]

# %% [markdown]
# Run node2vec

# %%
network = Runnode2vec("../data/final_data/ls-fgin_edge_list.edg")
master = master.merge(network, on='ensembl')
master.to_csv("../data/final_data/node_node2vec_data.csv", index=None)
master
# Out:
#   0%|          | 0/148540 [00:00<?, ?it/s]
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 network = Runnode2vec("../data/final_data/ls-fgin_edge_list.edg")
#       2 master = master.merge(network, on='ensembl')
#       3 master.to_csv("../data/final_data/node_node2vec_data.csv", index=None)
#
# File ~/Documents/github/lenskai/geneDRAGNN/data_preprocessing/create_node2vec_embeddings.py:14, in Runnode2vec(filepath)
#      11 edge_list = n2v.read_edg(filepath, weighted=False, directed=False)
#      12 emd = n2v.embed(dim=128, num_walks=10, walk_length=80, window_size=10, epochs=10)
# ---> 14 n2v_emd = pd.DataFrame(emd, n2v.IDlst)
#      16 n2v_emd.columns = ['network_' + str(col) for col in n2v_emd.columns]
#      18 return n2v_emd.reset_index().rename(columns={"index":"ensembl"})
#
# AttributeError: 'SparseOTF' object has no attribute 'IDlst'

# %%
print(dir(n2v))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(dir(n2v))
#
# NameError: name 'n2v' is not defined

# %%
label_col = 'gda_score'

node_dataset = dgn.merge(master['ensembl'], on='ensembl', how='right').fillna(0)

node_dataset[label_col] = node_dataset[label_col].map({0: pd.NA, 1:1})

print('# of positive labels: ', node_dataset[label_col].sum())

node_dataset

labels = node_dataset

labels[label_col] = labels[label_col].astype('Int64')

num_neg_samples = node_dataset[label_col].sum()

unlabeled_samples = labels.loc[labels['gda_score'].fillna(0)!=1]

num_random_samplings = 100
for i in range(num_random_samplings):
    negative_samples = np.random.choice(unlabeled_samples['ensembl'], size=num_neg_samples, replace=False)
    labels[f'label_{i}'] = labels[label_col]
    labels.loc[labels['ensembl'].isin(negative_samples), f'label_{i}'] = 0
labels
# Out:
# # of positive labels:  778
#                ensembl  gda_score  label_0  label_1  label_2  label_3  \
# 0      ENSG00000175899       <NA>     <NA>     <NA>     <NA>        0
# 1      ENSG00000128274       <NA>     <NA>     <NA>     <NA>     <NA>
# 2      ENSG00000094914       <NA>     <NA>        0     <NA>     <NA>
# 3      ENSG00000081760       <NA>     <NA>     <NA>     <NA>     <NA>
# 4      ENSG00000114771       <NA>     <NA>        0     <NA>     <NA>
# ...                ...        ...      ...      ...      ...      ...
# 14849  ENSG00000198455       <NA>     <NA>     <NA>     <NA>     <NA>
# 14850  ENSG00000070476       <NA>     <NA>     <NA>     <NA>     <NA>
# 14851  ENSG00000162378       <NA>     <NA>     <NA>     <NA>     <NA>
# 14852  ENSG00000159840       <NA>     <NA>     <NA>     <NA>     <NA>
# 14853  ENSG00000074755       <NA>        0     <NA>     <NA>     <NA>
#
#        label_4  label_5  label_6  label_7  ...  label_90  label_91  label_92  \
# 0         <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 1         <NA>        0     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 2         <NA>        0     <NA>        0  ...      <NA>      <NA>      <NA>
# 3         <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 4         <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>         0
# ...        ...      ...      ...      ...  ...       ...       ...       ...
# 14849     <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 14850     <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 14851     <NA>     <NA>     <NA>        0  ...      <NA>      <NA>         0
# 14852     <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
# 14853     <NA>     <NA>     <NA>     <NA>  ...      <NA>      <NA>      <NA>
#
#        label_93  label_94  label_95  label_96  label_97  label_98  label_99
# 0          <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 1          <NA>      <NA>         0      <NA>      <NA>      <NA>      <NA>
# 2          <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 3          <NA>         0      <NA>      <NA>      <NA>      <NA>      <NA>
# 4          <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# ...         ...       ...       ...       ...       ...       ...       ...
# 14849      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 14850      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 14851      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 14852      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# 14853      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
#
# [14854 rows x 102 columns]

# %%
labels.to_csv("../data/final_data/training_labels_trials.csv", index=None)
